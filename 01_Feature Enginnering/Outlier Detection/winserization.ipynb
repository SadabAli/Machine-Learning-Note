# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\alisa\OneDrive\Desktop\Machine Learning Note\Outlier Detection\weight-height.csv")
df.sample(5)
# Out:
#       Gender     Height      Weight
# 4999    Male  70.351880  198.903012
# 5523  Female  68.259311  171.856035
# 2256    Male  67.004076  190.555592
# 1073    Male  65.797953  162.027736
# 9263  Female  63.696380  145.573254

# %%
df.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# dtype: int64

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.distplot(df['Height'])

plt.subplot(1,2,2)
sns.distplot(df['Weight'])
# Out:
# C:\Users\alisa\AppData\Local\Temp\ipykernel_30920\3549514957.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# C:\Users\alisa\AppData\Local\Temp\ipykernel_30920\3549514957.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
upper_limit = df['Height'].quantile(.99)
lower_limit = df['Height'].quantile(.01)
print(upper_limit)
print(lower_limit)
# Out:
# 74.7857900583366
# 58.13441158671655

# %%
new_df= df[(df['Height']<=upper_limit) & (df['Height']>=lower_limit)]

# %%
new_df.shape
# Out:
# (9800, 3)

# %%
new_df.describe()
# Out:
#             Height       Weight
# count  9800.000000  9800.000000
# mean     66.364366   161.399489
# std       3.645075    30.933549
# min      58.134496    77.523774
# 25%      63.577162   136.322717
# 50%      66.318070   161.212928
# 75%      69.119896   186.753317
# max      74.785714   249.946283

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
sns.boxplot(new_df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
sns.distplot(new_df['Height'])
# Out:
# C:\Users\alisa\AppData\Local\Temp\ipykernel_30920\1622920233.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>
