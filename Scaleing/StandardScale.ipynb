# %%
import pandas as pd

# Raw link of the CSV file
url = "https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day24-standardization/Social_Network_Ads.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(url)

# %%
df.sample(3)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 148  15779862    Male   29            61000          0
# 96   15710257  Female   35            25000          0
# 202  15735549  Female   39           134000          1

# %%
df = df.iloc[:,2:]
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.sample(2)
# Out:
#      Age  EstimatedSalary  Purchased
# 197   20            36000          0
# 360   43           129000          1

# %%
X = df.iloc[:,0:2]
X
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=.3)

# %%
X_train.shape , X_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# Standard Scale

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scaler.fit(X_train) # Fit scaler to trin set , it will learn the parameters
# Out:
# StandardScaler()

# %%
scaler.mean_ #3.71178571e+01:Age, 7.14392857e+04: Salary
# Out:
# array([3.71178571e+01, 7.14392857e+04])

# %% [markdown]
# hamesha hum training se sikhte hai or transform karte hai train or test donon ko

# %%
# transformed train and test sets
X_train_Scaled=scaler.transform(X_train)
X_test_Scaled=scaler.transform(X_test)

# %%
X_train_Scaled # yahi problem hai , it takes df(X_train) and give np.array
# Out:
# array([[ 0.08556733, -0.01282575],
#        [-0.49642906,  0.83388253],
#        [-0.39942967, -0.8303372 ],
#        [-1.17542485, -1.44347078],
#        [ 0.95856191, -0.65515617],
#        [ 0.18256673,  1.47621295],
#        [-0.69042786,  0.24994578],
#        [ 0.08556733, -0.62595934],
#        [-0.20543087, -0.30479413],
#        [-0.88442666, -0.80114036],
#        [ 0.27956612, -0.42158148],
#        [ 0.18256673, -0.85953403],
#        [-0.20543087,  0.57111099],
#        [-0.20543087,  0.48352048],
#        [-0.20543087,  0.22074894],
#        [ 2.0255553 ,  2.11854337],
#        [-0.30243027, -0.8303372 ],
#        [-0.49642906,  1.33022876],
#        [-0.10843147, -1.12230557],
#        [ 0.95856191, -1.35588027],
#        [-0.98142606, -0.42158148],
#        [-0.98142606, -1.58945497],
#        [-0.10843147, -0.24640045],
#        [ 1.15256071,  0.51271732],
#        [ 1.15256071, -0.94712455],
#        [ 1.34655951, -1.41427394],
#        [-0.88442666, -1.00551822],
#        [-0.01143207,  0.22074894],
#        [ 0.76456312,  0.22074894],
#        [-1.07842546, -1.20989608],
#        [-0.39942967,  1.21344141],
#        [-1.07842546, -1.64784864],
#        [-0.30243027, -0.8303372 ],
#        [ 0.27956612,  1.03826039],
#        [-0.30243027, -1.35588027],
#        [-0.69042786, -0.27559729],
#        [ 2.21955409, -0.85953403],
#        [-1.17542485,  0.54191415],
#        [ 0.08556733, -0.5967625 ],
#        [ 1.05556131, -1.12230557],
#        [ 1.5405583 ,  0.95066988],
#        [-0.88442666,  0.45432364],
#        [-0.20543087, -0.62595934],
#        [-0.39942967, -0.07121943],
#        [-1.75742124, -1.35588027],
#        [-0.20543087, -0.01282575],
#        [ 0.27956612,  0.1039616 ],
#        [ 0.37656552, -0.24640045],
#        [ 0.47356492, -0.04202259],
#        [ 1.24956011,  0.48352048],
#        [-0.20543087, -0.97632138],
#        [-0.88442666, -1.15150241],
#        [ 0.18256673,  1.82657499],
#        [-0.20543087, -1.50186445],
#        [ 0.18256673,  1.82657499],
#        [ 0.27956612,  0.01637108],
#        [ 0.18256673,  0.16235527],
#        [ 1.44355891,  1.24263825],
#        [-0.98142606, -0.50917199],
#        [ 2.21955409,  1.06745723],
#        [ 1.24956011, -0.80114036],
#        [-0.59342846,  0.13315843],
#        [-0.88442666,  0.36673313],
#        [ 1.5405583 , -1.09310873],
#        [ 1.05556131,  1.38862244],
#        [ 1.15256071,  0.42512681],
#        [-1.27242425, -0.47997515],
#        [-0.98142606,  0.51271732],
#        [-0.01143207,  0.01637108],
#        [-0.69042786,  0.22074894],
#        [-0.69042786,  1.03826039],
#        [ 1.05556131, -1.0639119 ],
#        [-0.69042786,  0.45432364],
#        [ 0.37656552, -0.3631878 ],
#        [-0.78742726,  0.33753629],
#        [-1.66042185,  0.30833946],
#        [-0.01143207, -0.53836882],
#        [ 0.95856191, -0.8303372 ],
#        [ 1.05556131,  2.03095286],
#        [-1.07842546,  0.42512681],
#        [-0.01143207,  0.24994578],
#        [-0.78742726,  2.23533072],
#        [ 0.37656552,  0.01637108],
#        [-1.07842546, -0.56756566],
#        [ 0.66756372,  1.97255918],
#        [-1.75742124,  0.39592997],
#        [-0.30243027,  0.01637108],
#        [ 1.34655951,  2.17693704],
#        [ 0.37656552, -0.01282575],
#        [-1.75742124, -1.53106129],
#        [-0.49642906, -1.56025813],
#        [ 2.12255469,  0.13315843],
#        [-1.46642305, -1.56025813],
#        [-1.07842546,  0.24994578],
#        [ 1.34655951,  1.82657499],
#        [-0.20543087, -0.71354985],
#        [-0.30243027,  1.18424457],
#        [ 1.05556131,  1.73898448],
#        [-0.98142606, -1.50186445],
#        [ 1.15256071,  0.07476476],
#        [-0.39942967,  2.26452755],
#        [-1.07842546, -1.58945497],
#        [ 0.47356492, -0.18800678],
#        [ 1.9285559 ,  0.07476476],
#        [ 0.76456312, -1.15150241],
#        [ 1.15256071, -1.03471506],
#        [ 0.08556733, -0.01282575],
#        [-0.20543087, -0.39238464],
#        [ 2.21955409, -0.74274669],
#        [ 0.47356492,  1.06745723],
#        [-1.07842546,  0.36673313],
#        [ 0.18256673,  0.04556792],
#        [-0.49642906,  0.42512681],
#        [-0.01143207,  0.19155211],
#        [-1.36942365, -1.26828976],
#        [ 0.95856191, -1.09310873],
#        [ 0.18256673,  0.71709518],
#        [ 0.37656552,  0.45432364],
#        [ 0.95856191,  2.11854337],
#        [ 0.27956612, -0.42158148],
#        [ 0.76456312, -1.44347078],
#        [-0.20543087,  0.04556792],
#        [-0.98142606,  0.36673313],
#        [ 1.15256071, -1.26828976],
#        [ 2.21955409, -1.09310873],
#        [ 2.21955409,  0.8922762 ],
#        [-1.36942365, -0.15880994],
#        [-0.49642906,  2.29372439],
#        [-0.01143207,  0.62950467],
#        [-0.10843147, -0.62595934],
#        [-0.01143207,  0.16235527],
#        [-0.10843147,  2.11854337],
#        [-0.78742726,  0.24994578],
#        [ 1.05556131,  1.82657499],
#        [ 0.27956612, -0.42158148],
#        [-1.75742124, -0.04202259],
#        [ 0.86156251, -0.3631878 ],
#        [-0.88442666,  0.39592997],
#        [-0.10843147, -0.50917199],
#        [-0.59342846,  0.07476476],
#        [ 0.08556733,  1.21344141],
#        [ 0.27956612, -0.01282575],
#        [ 0.76456312, -0.77194352],
#        [-1.07842546,  0.27914262],
#        [ 0.66756372, -0.94712455],
#        [-1.27242425,  0.51271732],
#        [-1.17542485,  0.45432364],
#        [-1.85442064, -0.80114036],
#        [ 1.44355891, -1.47266762],
#        [-0.20543087, -0.42158148],
#        [ 0.37656552, -0.56756566],
#        [-1.27242425, -1.29748659],
#        [-0.20543087, -0.80114036],
#        [ 1.7345571 , -0.94712455],
#        [-0.01143207,  0.24994578],
#        [-1.85442064, -0.10041627],
#        [ 1.15256071,  2.03095286],
#        [-0.20543087, -1.35588027],
#        [-0.01143207,  0.07476476],
#        [ 0.18256673, -0.30479413],
#        [ 0.47356492,  0.24994578],
#        [ 1.5405583 ,  0.01637108],
#        [ 1.7345571 ,  1.70978765],
#        [-0.01143207,  1.91416551],
#        [ 1.8315565 , -0.33399096],
#        [ 1.05556131,  0.07476476],
#        [ 0.95856191,  0.97986671],
#        [-1.07842546,  1.3594256 ],
#        [ 1.05556131,  0.54191415],
#        [-1.66042185,  0.07476476],
#        [-0.59342846, -0.39238464],
#        [-1.36942365,  0.30833946],
#        [ 0.27956612, -0.30479413],
#        [-0.10843147, -0.33399096],
#        [-0.20543087,  0.1039616 ],
#        [ 0.37656552, -0.33399096],
#        [-0.59342846,  1.3594256 ],
#        [ 1.9285559 ,  1.47621295],
#        [ 0.27956612, -0.33399096],
#        [-0.78742726,  0.1039616 ],
#        [ 1.44355891,  2.29372439],
#        [-0.10843147,  0.80468569],
#        [ 2.12255469, -0.85953403],
#        [ 0.57056432,  1.18424457],
#        [-0.98142606,  0.54191415],
#        [-1.17542485,  0.24994578],
#        [-1.46642305, -0.47997515],
#        [ 1.8315565 ,  0.95066988],
#        [-0.69042786,  1.30103192],
#        [ 0.08556733, -0.30479413],
#        [ 0.08556733, -0.62595934],
#        [-1.66042185,  0.42512681],
#        [-0.59342846, -0.01282575],
#        [-1.66042185, -1.41427394],
#        [ 0.86156251, -0.88873087],
#        [-0.98142606,  0.71709518],
#        [-1.66042185, -1.03471506],
#        [ 0.47356492,  0.1039616 ],
#        [-0.78742726, -0.71354985],
#        [-0.49642906, -1.56025813],
#        [-0.39942967, -1.18069924],
#        [ 0.86156251,  0.71709518],
#        [-1.27242425, -0.47997515],
#        [-1.75742124, -1.32668343],
#        [ 0.95856191, -1.20989608],
#        [-0.69042786, -0.65515617],
#        [ 0.37656552,  0.22074894],
#        [ 1.9285559 , -1.12230557],
#        [-1.07842546, -1.64784864],
#        [ 0.27956612, -0.71354985],
#        [-1.56342245, -1.6186518 ],
#        [-0.10843147,  1.56380346],
#        [ 0.37656552,  0.01637108],
#        [ 0.27956612,  2.06014969],
#        [-0.59342846, -1.56025813],
#        [ 2.0255553 ,  0.68789834],
#        [-0.78742726, -0.30479413],
#        [-1.46642305,  0.27914262],
#        [-0.20543087,  2.20613388],
#        [-0.20543087, -0.18800678],
#        [-0.69042786,  0.51271732],
#        [-1.66042185,  0.30833946],
#        [ 0.27956612,  0.19155211],
#        [-1.27242425, -1.41427394],
#        [-0.88442666, -0.47997515],
#        [-0.49642906,  1.33022876],
#        [-0.20543087,  0.1039616 ],
#        [-1.07842546, -1.0639119 ],
#        [-1.17542485, -1.12230557],
#        [ 0.57056432,  1.68059081],
#        [ 0.08556733,  1.18424457],
#        [ 0.86156251,  1.33022876],
#        [ 0.37656552,  0.24994578],
#        [ 0.47356492,  2.26452755],
#        [ 0.27956612, -0.3631878 ],
#        [ 0.47356492, -0.21720361],
#        [-0.10843147, -0.56756566],
#        [-0.49642906,  1.41781927],
#        [-0.10843147,  1.3594256 ],
#        [ 0.47356492,  0.24994578],
#        [ 1.44355891,  1.94336234],
#        [ 2.12255469,  0.48352048],
#        [ 2.0255553 ,  0.86307936],
#        [-1.07842546, -1.6186518 ],
#        [-1.36942365, -0.68435301],
#        [ 0.37656552, -0.77194352],
#        [-1.27242425, -1.53106129],
#        [ 0.37656552,  0.01637108],
#        [-0.01143207, -0.47997515],
#        [-1.85442064,  0.30833946],
#        [-0.88442666, -0.3631878 ],
#        [ 1.5405583 ,  0.30833946],
#        [ 0.18256673, -0.3631878 ],
#        [-0.10843147,  1.5930003 ],
#        [-0.78742726, -0.8303372 ],
#        [ 0.86156251, -1.41427394],
#        [ 0.37656552,  0.01637108],
#        [ 0.76456312, -1.44347078],
#        [ 0.47356492, -0.53836882],
#        [-0.01143207, -1.12230557],
#        [ 1.7345571 ,  1.56380346],
#        [ 0.47356492, -0.50917199],
#        [ 1.15256071,  0.48352048],
#        [-0.98142606,  0.48352048],
#        [-0.20543087, -0.47997515],
#        [-0.98142606, -0.39238464],
#        [ 1.15256071, -0.18800678],
#        [-0.98142606, -0.39238464],
#        [-1.85442064,  0.42512681],
#        [-0.20543087, -0.33399096],
#        [ 0.95856191, -1.50186445],
#        [ 1.6375577 , -1.32668343],
#        [ 0.95856191,  1.21344141],
#        [ 0.86156251, -1.44347078],
#        [-1.07842546, -0.8303372 ],
#        [ 0.37656552, -0.5967625 ],
#        [-0.30243027,  1.27183509],
#        [-1.85442064, -0.56756566],
#        [ 0.47356492,  0.04556792],
#        [-0.98142606,  1.91416551]])

# %%
X_train_Scaled=pd.DataFrame(X_train_Scaled,columns=X_train.columns)
X_test_Scaled=pd.DataFrame(X_test_Scaled,columns=X_test.columns)

# %%
X_train_Scaled.sample(3)
# Out:
#           Age  EstimatedSalary
# 122 -0.981426         0.366733
# 104  0.764563        -1.151502
# 0    0.085567        -0.012826

# %%
X_train.describe()
# Out:
#               Age  EstimatedSalary
# count  280.000000       280.000000
# mean    37.117857     71439.285714
# std     10.327801     34311.610617
# min     18.000000     15000.000000
# 25%     29.000000     45000.000000
# 50%     37.000000     71000.000000
# 75%     44.250000     88250.000000
# max     60.000000    150000.000000

# %%
X_train_Scaled.describe()
# Out:
#                 Age  EstimatedSalary
# count  2.800000e+02     2.800000e+02
# mean   2.505932e-16     1.134014e-16
# std    1.001791e+00     1.001791e+00
# min   -1.854421e+00    -1.647849e+00
# 25%   -7.874273e-01    -7.719435e-01
# 50%   -1.143207e-02    -1.282575e-02
# 75%    6.918136e-01     4.908197e-01
# max    2.219554e+00     2.293724e+00

# %%
np.round(X_train_Scaled.describe(),1)
# mean = 0 , std = 1
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.0             -0.0
# 75%      0.7              0.5
# max      2.2              2.3

# %% [markdown]
# Effecting of scaling

# %%
from matplotlib import pyplot as plt
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_Scaled['Age'], X_train_Scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()

# %% [markdown]
# bas mean centerd ho gaya or x,y-axix normalized ho gaya

# %%
import seaborn as sns
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_Scaled['Age'], ax=ax2)
sns.kdeplot(X_train_Scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# Comparision Of destributiom

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Age Distribution Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)

# after scaling
ax2.set_title('Age Distribution After Standard Scaling')
sns.kdeplot(X_train_Scaled['Age'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('Salary Distribution Standard Scaling')
sns.kdeplot(X_train_Scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# Why Scaling is important

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log_scaled = LogisticRegression()

# %%
log.fit(X_train,y_train)
log_scaled.fit(X_train_Scaled,y_train)
# Out:
# LogisticRegression()

# %%
ypred = log.predict(X_test)
ypred_scale = log_scaled.predict(X_test_Scaled)

# %%
from sklearn.metrics import accuracy_score
print("Actual" , accuracy_score(y_test,ypred))
print("Scaled" , accuracy_score(y_test,ypred_scale))
 # kuch hua nahi lekin Actual me kam aana chaiya or scaled me jyada
# Out:
# Actual 0.8333333333333334
# Scaled 0.8333333333333334
