# %%
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
X,y = make_classification(n_samples=5, n_classes=2,
                               n_features=2, n_informative=2, n_redundant=0,
                               random_state=0)
clf = DecisionTreeClassifier()
clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clf)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[1] <= -0.894\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[0] <= 1.01\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
clf.feature_importances_ # Feature IMP.of DT
# Out:
# array([0.625, 0.375])

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=4)
rf.fit(X,y)
# Out:
# RandomForestClassifier(n_estimators=4)

# %%
rf.feature_importances_ #Feature IMP.of RF
# Out:
# array([0.34375, 0.65625])

# %%
print(rf.estimators_[0].feature_importances_)# 1st DT
print(rf.estimators_[1].feature_importances_)
print(rf.estimators_[2].feature_importances_)
print(rf.estimators_[3].feature_importances_)# 4th DT
# Out:
# [0. 1.]
# [1. 0.]
# [0.375 0.625]
# [0. 1.]
